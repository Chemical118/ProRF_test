# %%
using ProRF

# %%
R = RF("Data/RBs")
X, Y, L = get_data(R, 'D', norm=true);

# %%
size(X)
# Out:
# (75, 85)

# %%
RI = RFI(R, 2:1:20, 200:200:2000);

# %%
MeZ, SdZ = iter_get_reg_value(RI, X, Y, 10)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# ([0.3191734107062307 0.3145726997528413 … 0.24858128490562748 0.24800707713620698; 0.32743964019527205 0.3216824677363822 … 0.2522398726781372 0.25130012863239304; … ; 0.28815214011689566 0.28469780434860487 … 0.2499223026915125 0.24934291938573336; 0.29601052010721945 0.2919457503064666 … 0.2516920965391982 0.2509507723828611], [0.06619280207711525 0.06365331358080122 … 0.040392273739260076 0.040664823755612076; 0.08013051390327355 0.07614187611799637 … 0.041451393317949524 0.04176106999079703; … ; 0.07739361154661993 0.07334820070613664 … 0.04866117698783001 0.0486489070370785; 0.07514480488814515 0.0701021095604255 … 0.04820548006692298 0.04829914725056369])

# %%
view_reg3d(RI, MeZ, title="NRMSE value", azim=120, scale=3)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
view_reg3d(RI, SdZ, title="NRMSE SD value", azim=120, scale=3);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
rf_model(X, Y, 10, 2000)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# NRMSE : 0.273464
# RandomForestRegressor
# n_trees:             2000
# n_subfeatures:       10
# partial_sampling:    0.7
# max_depth:           -1
# min_samples_leaf:    1
# min_samples_split:   2
# min_purity_increase: 0.0
# ensemble:            Ensemble of Decision Trees
# Trees:      2000
# Avg Leaves: 24.6985
# Avg Depth:  9.1325
