# %%
using ProRF

# %%
R = RF("Data/GB1")
X, Y, L = get_data(R, 'C', norm=true);
RI = RFI(R, 5:1:9, 400:250:1400)
# Out:
# RFI("Data/GB1/data.fasta", "Data/GB1/data.xlsx", 1, 5:1:9, 400:250:1400)

# %%
size(X)
# Out:
# (536962, 55)

# %%
rf_model(X, Y, 6, 500, max_depth=50)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# NRMSE : 0.117138
# RandomForestRegressor
# n_trees:             500
# n_subfeatures:       6
# partial_sampling:    0.7
# max_depth:           50
# min_samples_leaf:    1
# min_samples_split:   2
# min_purity_increase: 0.0
# ensemble:            Ensemble of Decision Trees
# Trees:      500
# Avg Leaves: 34765.656
# Avg Depth:  50.0

# %%
rf_model(X, Y, 6, 500)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# NRMSE : 0.110745
# RandomForestRegressor
# n_trees:             500
# n_subfeatures:       6
# partial_sampling:    0.7
# max_depth:           -1
# min_samples_leaf:    1
# min_samples_split:   2
# min_purity_increase: 0.0
# ensemble:            Ensemble of Decision Trees
# Trees:      500
# Avg Leaves: 176676.268
# Avg Depth:  228.716

# %%
rf_model(X, Y, 7, 500, max_depth=160)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# NRMSE : 0.109380
# RandomForestRegressor
# n_trees:             500
# n_subfeatures:       7
# partial_sampling:    0.7
# max_depth:           160
# min_samples_leaf:    1
# min_samples_split:   2
# min_purity_increase: 0.0
# ensemble:            Ensemble of Decision Trees
# Trees:      500
# Avg Leaves: 170406.88
# Avg Depth:  160.0

# %%
rf_model(X, Y, 7, 500, max_depth=200)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# NRMSE : 0.110250
# RandomForestRegressor
# n_trees:             500
# n_subfeatures:       7
# partial_sampling:    0.7
# max_depth:           200
# min_samples_leaf:    1
# min_samples_split:   2
# min_purity_increase: 0.0
# ensemble:            Ensemble of Decision Trees
# Trees:      500
# Avg Leaves: 176277.92
# Avg Depth:  200.0

# %%
rf_model(X, Y, 7, 500, max_depth=190)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# NRMSE : 0.108871
# RandomForestRegressor
# n_trees:             500
# n_subfeatures:       7
# partial_sampling:    0.7
# max_depth:           190
# min_samples_leaf:    1
# min_samples_split:   2
# min_purity_increase: 0.0
# ensemble:            Ensemble of Decision Trees
# Trees:      500
# Avg Leaves: 175999.078
# Avg Depth:  190.0

# %%
rf_model(X, Y, 7, 500, max_depth=180)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# NRMSE : 0.109303
# RandomForestRegressor
# n_trees:             500
# n_subfeatures:       7
# partial_sampling:    0.7
# max_depth:           180
# min_samples_leaf:    1
# min_samples_split:   2
# min_purity_increase: 0.0
# ensemble:            Ensemble of Decision Trees
# Trees:      500
# Avg Leaves: 175422.888
# Avg Depth:  180.0

# %%
rf_model(X, Y, 7, 500, max_depth=170)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# NRMSE : 0.108871
# RandomForestRegressor
# n_trees:             500
# n_subfeatures:       7
# partial_sampling:    0.7
# max_depth:           170
# min_samples_leaf:    1
# min_samples_split:   2
# min_purity_increase: 0.0
# ensemble:            Ensemble of Decision Trees
# Trees:      500
# Avg Leaves: 173958.828
# Avg Depth:  170.0

# %%
rf_model(X, Y, 8, 500, max_depth=170)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# NRMSE : 0.110571
# RandomForestRegressor
# n_trees:             500
# n_subfeatures:       8
# partial_sampling:    0.7
# max_depth:           170
# min_samples_leaf:    1
# min_samples_split:   2
# min_purity_increase: 0.0
# ensemble:            Ensemble of Decision Trees
# Trees:      500
# Avg Leaves: 173950.102
# Avg Depth:  170.0

# %%
rf_model(X, Y, 6, 500, max_depth=170)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# NRMSE : 0.110337
# RandomForestRegressor
# n_trees:             500
# n_subfeatures:       6
# partial_sampling:    0.7
# max_depth:           170
# min_samples_leaf:    1
# min_samples_split:   2
# min_purity_increase: 0.0
# ensemble:            Ensemble of Decision Trees
# Trees:      500
# Avg Leaves: 174063.588
# Avg Depth:  170.0

# %%
rf_model(X, Y, 7, 500, max_depth=190) # target
